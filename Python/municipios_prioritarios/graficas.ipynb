# %% [markdown]
# ## Funciones

# %%
import sys
sys.path.append('../1_funciones')
from municipios_prioritarios import municipios_prioritarios

import pandas as pd

# %% [markdown]
# ## Gráfica

# %%
fechas = pd.date_range(start='2024-01-01', end='2025-07-01', freq='MS')

valores = [
    2.1, 0.8, 1.7, 2.5, 1.2, 2.9, 0.6, 1.5, 2.3, 1.1, 2.7, 1.9, 0.9, 2.6, 1.4,
    2.2, 0.7, 2.8, 1.3
]  # 19 valores para 19 fechas

linea = pd.DataFrame({
    'FECHA': fechas,
    'CATEGORIA': ['Promedio diario'] * len(fechas),
    'VALOR': valores
})

print(linea.shape); linea.head(5)
# Out:
# (19, 3)
#        FECHA        CATEGORIA  VALOR
# 0 2024-01-01  Promedio diario    2.1
# 1 2024-02-01  Promedio diario    0.8
# 2 2024-03-01  Promedio diario    1.7
# 3 2024-04-01  Promedio diario    2.5
# 4 2024-05-01  Promedio diario    1.2

# %%
data_ca1 = {
    'Promedio Sept.\n2024': [1.9],
    'Promedio periodo 2': [0.7],
    'Diferencia': [-63.1]
}

df_ca1 = pd.DataFrame(data_ca1)
df_ca1
# Out:
#    Promedio Sept.\n2024  Promedio periodo 2  Diferencia
# 0                   1.9                 0.7       -63.1

# %%
data_ca2 = {
    'Promedio Ene-\nJul. 2024': [1.3],
    'Promedio periodo 2': [1.5],
    'Diferencia': [8.2]
}

df_ca2 = pd.DataFrame(data_ca2)
df_ca2
# Out:
#    Promedio Ene-\nJul. 2024  Promedio periodo 2  Diferencia
# 0                       1.3                 1.5         8.2

# %%
municipios_prioritarios(
    df_caja1=df_ca1,
    df_caja2=df_ca2,
    titulo='TÍTULO',
    df_linea=linea,
    fondo='transparente',
)
# Out:
# Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.
# /home/misael/Github/Repositorios/graficas_gob/Python/municipios_prioritarios/../1_funciones/funciones.py:294: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
