# %%
import sys
sys.path.append('../1_funciones')
from treemap import treemap

import pandas as pd
import numpy as np

# %% [markdown]
# ### Dataframe de ejemplo para el treemap

# %%
import pandas as pd

victimas_por_entidad = pd.DataFrame({
    'ENTIDAD FEDERATIVA': [
        'Jalisco', 'Guanajuato', 'Michoacán', 'Sonora', 'Oaxaca',
        'Estado de México Estado de México Estado de México Estado de México Estado de México Estado de México', 'Durango', 'Nuevo León', 'Coahuila', 'Tamaulipas',
        'Puebla', 'Ciudad de México', 'Guerrero', 'Veracruz', 'Chiapas'
    ],
    'NUMERO DE VICTIMAS': [
        910, 750, 664, 516, 508,
        485, 380, 320, 264, 171,
        156, 152, 137, 121, 70
    ]
})
print(victimas_por_entidad.shape); victimas_por_entidad.head(5)
# Out:
# (15, 2)
#   ENTIDAD FEDERATIVA  NUMERO DE VICTIMAS
# 0            Jalisco                 910
# 1         Guanajuato                 750
# 2          Michoacán                 664
# 3             Sonora                 516
# 4             Oaxaca                 508

# %%
treemap(victimas_por_entidad, 
        nombre="victimas_por_entidad",
        porce_parentesis=True,
        paleta_colores=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6'],
        )
# Out:
# [DEBUG] Área: 0.162384 | Etiqueta: 'Jalisco' | FontSize: 26.0
# [DEBUG] Área: 0.133833 | Etiqueta: 'Guanajuato' | FontSize: 26.0
# [DEBUG] Área: 0.118487 | Etiqueta: 'Michoacán' | FontSize: 26.0
# [DEBUG] Área: 0.092077 | Etiqueta: 'Sonora' | FontSize: 26.0
# [DEBUG] Área: 0.090650 | Etiqueta: 'Oaxaca' | FontSize: 26.0
# [DEBUG] Área: 0.086545 | Etiqueta: 'Estado de México Estado de México Estado de México Estado de México Estado de México Estado de México' | FontSize: 26.0
# [DEBUG] Área: 0.067809 | Etiqueta: 'Durango' | FontSize: 20
# [DEBUG] Área: 0.057102 | Etiqueta: 'Nuevo León' | FontSize: 24
# [DEBUG] Área: 0.047109 | Etiqueta: 'Coahuila' | FontSize: 24
# [DEBUG] Área: 0.030514 | Etiqueta: 'Tamaulipas' | FontSize: 16
# [DEBUG] Área: 0.027837 | Etiqueta: 'Puebla' | FontSize: 14
# [DEBUG] Área: 0.027123 | Etiqueta: 'Ciudad de México' | FontSize: 14
# [DEBUG] Área: 0.024447 | Etiqueta: 'Guerrero' | FontSize: 14
# [DEBUG] Área: 0.021592 | Etiqueta: 'Veracruz' | FontSize: 14
# ...

# %%
camiones = pd.DataFrame({
    'ENTIDAD FEDERATIVA': [
        'Tractocamión Articulado', 'Autobús', 'Camión Unitario', 'Tractocamión Doblemente Articulado', 'Tractocamión',
        'C-R'
    ],
    'NUMERO DE VICTIMAS': [
        700, 572, 226, 69, 7,
        3
    ]
})
print(camiones.shape); camiones.head(5)
# Out:
# (6, 2)
#                    ENTIDAD FEDERATIVA  NUMERO DE VICTIMAS
# 0             Tractocamión Articulado                 700
# 1                             Autobús                 572
# 2                     Camión Unitario                 226
# 3  Tractocamión Doblemente Articulado                  69
# 4                        Tractocamión                   7

# %%
treemap(camiones,
        nombre="camiones",
        porce_parentesis=True,
        paleta_colores=['#10302c','#671435','#006157','#a36c2a','#d8b878','#7f7f7f'],
        ancho_fig=16,
        alto_fig=14,
        color_borde_rec="black",
        ancho_borde_rec=6,
        tipo_letra='Arial',
        ajusta_sep_valor=0.01,
        ajusta_tam_letra=2.8, 
        ajusta_posY_texto=0.62,
        )
# Out:
# [DEBUG] Área: 0.443881 | Etiqueta: 'Tractocamión Articulado' | FontSize: 72.8
# [DEBUG] Área: 0.362714 | Etiqueta: 'Autobús' | FontSize: 72.8
# [DEBUG] Área: 0.143310 | Etiqueta: 'Camión Unitario' | FontSize: 72.8
# [DEBUG] Área: 0.043754 | Etiqueta: 'Tractocamión Doblemente Articulado' | FontSize: 67
# [DEBUG] Área: 0.004439 | Etiqueta: 'Tractocamión' | FontSize: 14
# [DEBUG] Área: 0.001902 | Etiqueta: 'C-R' | FontSize: 8
# Scour processed file "output/camiones.svg" in 7 ms: 3661/6119 bytes new/orig -> 59.8%
