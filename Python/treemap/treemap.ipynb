# %%
import sys
sys.path.append('../1_funciones')
from treemap import treemap
from barras_verticales import barras_verticales

import pandas as pd
import numpy as np

# %% [markdown]
# # Slide 1

# %%
fechas_diferentes = pd.to_datetime([
    '2025-03-02', '2025-03-09', '2025-03-16', '2025-03-23', '2025-03-30',
    '2025-04-06', '2025-04-13', '2025-04-20', '2025-04-27', '2025-05-04',
    '2025-05-11', '2025-05-18', '2025-05-25', '2025-06-01', '2025-06-08',
    '2025-06-15', '2025-06-22', '2025-06-29', '2025-07-06', '2025-07-13'
])

tipo_del = pd.DataFrame({
    'Fechas': fechas_diferentes,
    'Cantidad 1': [
        0, 0.71, 0.57, 0.86, 0.14, 0, 0, 0.14, 1, 0.14, 1, 0.29, 0, 0.14, 0, 0, 0.14, 0, 0.29, 0.2
    ],
    'Cantidad 2': [
        0, 3, 2.86, 3.71, 5.86, 4.86, 5.71, 3.43, 3.57, 5, 3.57, 3.14, 3.71, 3.57, 4.29, 3.29, 3.57, 3.57, 2.29, 3.8
    ],
    'Cantidad 3': [
        4.33, 5.71, 10.14, 9, 9, 9.43, 4.43, 8, 8.71, 8.57, 12.29, 7.14, 10.86, 9.14, 7.57, 8.43, 4.86, 3.86, 7.57, 2.4
    ]
})
print(tipo_del.shape); tipo_del.head(5)
# Out:
# (20, 4)
#       Fechas  Cantidad 1  Cantidad 2  Cantidad 3
# 0 2025-03-02        0.00        0.00        4.33
# 1 2025-03-09        0.71        3.00        5.71
# 2 2025-03-16        0.57        2.86       10.14
# 3 2025-03-23        0.86        3.71        9.00
# 4 2025-03-30        0.14        5.86        9.00

# %%
barras_verticales(tipo_del, 
       nombre="tipo_del", 
       ancho_barra=0.8, 
       tipo_letra='Montserrat',
       valor_barra=True, 
       tam_letra_valor_barra=14,
       porce_barra=False, 
       porce_total=False,
       ordenar_por='etiqueta',
       orden='ascendente',
       area_min=500,
       leyenda=True,
       #sustituir_etiquetas=etiquetas_nuevas,
       tam_letra_valor_capsu=18,
       paleta_colores=['#a7802d', '#621132', '#124741'],
       quitar_capsu=True,
       ajusta_pos_capsu=0.00,
       color_valor_capsu='black',
       color_valor_barra='white',
)
# Out:
# Scour processed file "output/tipo_del.svg" in 70 ms: 24917/39910 bytes new/orig -> 62.4%

# %%
nuevas_etiquetas = [
    '2-8\nMarzo', '9-15\nMarzo', '16-22\nMarzo', '23-29\nMarzo', '30-5\nAbril',
    '6-12\nAbril', '13-19\nAbril', '20-26\nAbril', '27-3\nMayo', '4-10\nMayo',
    '11-17\nMayo', '18-24\nMayo', '25-31\nMayo', '1-7\nJunio', '8-14\nJunio',
    '15-21\nJunio', '22-28\nJunio', '29-5\nJulio', '6-12\nJulio', '13-19\nJulio'
]

barras_verticales(tipo_del, 
       nombre="tipo_del", 
       ancho_barra=0.9, 
       tipo_letra='Montserrat',
       valor_barra=True, 
       tam_letra_valor_barra=14,
       porce_barra=False, 
       porce_total=False,
       ordenar_por='etiqueta',
       orden='ascendente',
       area_min=500,
       leyenda=True,
       sustituir_etiquetas=nuevas_etiquetas,
       tam_letra_valor_capsu=18,
       paleta_colores=['#a7802d', '#621132', '#124741'],
       quitar_capsu=True,
       ajusta_pos_capsu=0.00,
       color_valor_capsu='black',
       color_valor_barra='white',
       orientacion_etiqu_ejeX='horizontal',
       tam_letra_ejeX=18,
       color_letra_ejeX='#7c7c7c',
       tam_letra_ejeY=25,
       color_letra_ejeY='#7c7c7c',
       fondo='white',
)
# Out:
# Scour processed file "output/tipo_del.svg" in 44 ms: 26318/42974 bytes new/orig -> 61.2%

# %% [markdown]
# ## Slide 2

# %%
tipo_vehiculo = pd.DataFrame({
    'Tipo de vehiculo': [
        'Tractocamión Articulado', 'Autobús', 'Camión Unitario', 'Tractocamión Doblemente Articulado', 'Tractocamión',
        'C-R'
    ],
    'Victimas': [
        700, 572, 226, 69, 7,
        3
    ]
})
print(tipo_vehiculo.shape); tipo_vehiculo.head(5)
# Out:
# (6, 2)
#                      Tipo de vehiculo  Victimas
# 0             Tractocamión Articulado       700
# 1                             Autobús       572
# 2                     Camión Unitario       226
# 3  Tractocamión Doblemente Articulado        69
# 4                        Tractocamión         7

# %%
treemap(tipo_vehiculo,
        nombre="tipo_vehiculo",
        porce_parentesis=True,
        paleta_colores=['#10302c','#671435','#006157','#a36c2a','#d8b878','#7f7f7f'],
        ancho_fig=16,
        alto_fig=14,
        color_borde_rec="black",
        ancho_borde_rec=6,
        tipo_letra='Arial',
        ajusta_sep_valor=0.01,
        ajusta_tam_letra=2.8, 
        ajusta_posY_texto=0.62,
        )
# Out:
# /home/misael/Github/Repositorios/graficas_gob/Python/treemap/../1_funciones/treemap.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    700.0
# 1    572.0
# 2    226.0
# 3     69.0
# 4      7.0
# 5      3.0
# Name: Victimas, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   victimas_por_entidad.iloc[:, 1] = pd.to_numeric(
# Scour processed file "output/tipo_vehiculo.svg" in 12 ms: 3661/6119 bytes new/orig -> 59.8%
