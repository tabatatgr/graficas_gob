# %%
import sys
sys.path.append('../1_funciones')
from barras_verticales import barras_verticales

import pandas as pd
import numpy as np

# %% [markdown]
# ## Barras coloreadas por categorias

# %%
paises10 = [
    "México", "Brasil", "Argentina", "Chile", "Colombia", "Perú", "Venezuela", "Ecuador", "Bolivia", "Uruguay",
    "Paraguay", "Costa Rica", "Panamá", "Guatemala", "Honduras", "El Salvador", "Nicaragua", "Cuba", "República Dominicana", "Puerto Rico",
    "España", "Portugal", "Francia", "Italia", "Alemania", "Reino Unido", "Rusia", "China", "Japón", "India"
]

valores10 = [
    -0.55, -0.48, -0.42, -0.39, -0.35, -0.31, -0.28, -0.22, -0.18, -0.13,
    -0.09, -0.05, 0.00, 0.04, 0.09, 0.13, 0.18, 0.22, 0.27, 0.31,
    0.36, 0.40, 0.45, 0.49, 0.54, 0.58, 0.63, 0.67, 0.72, 0.78
]

categorias10 = [
    "América", "América", "América", "América", "América", "América", "América", "América", "América", "América",
    "América", "América", "América", "América", "América", "América", "América", "América", "América", "América",
    "Europa", "Europa", "Europa", "Europa", "Europa", "Europa", "Europa", "Asia", "Asia", "Asia"
]

df_categorias10 = pd.DataFrame({
    "País": paises10,
    "Valor": valores10,
    "Categorias": categorias10
})

print(df_categorias10.shape); df_categorias10.head(5)
# Out:
# (30, 3)
#         País  Valor Categorias
# 0     México  -0.55    América
# 1     Brasil  -0.48    América
# 2  Argentina  -0.42    América
# 3      Chile  -0.39    América
# 4   Colombia  -0.35    América

# %%
barras_verticales(df_categorias10, 
       nombre="barras coloreadas por categorías", 
       ancho_barra=0.7, 
       tipo_letra='Montserrat',
       tam_letra_ejeX=35,
       tam_letra_ejeY=30,
       tam_letra_valor_capsu=35,
       ajusta_pos_capsu = 0.08,
       ajusta_pos_capsu_neg=0.08,
       ordenar_por='valor',
       orden='ascendente',
       porce_barra=False,
       tam_porce_total=35,
       separar_por_total=-0.0,
       alinea_capsu=True,
       alinea_texto_barra=True,
       porce_total=False,
       y_limits=(-1.3, 1.5),
       valor_barra=False,
       sustituir_etiquetas_ejeY=nue_etiqu_ejeY,
       col_categorias='Categorias',
       leyenda=True,
       )
# Out:
# /home/misael/Github/Repositorios/graficas_gob/Python/barras_verticales/../1_funciones/barras_verticales.py:986: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(sustituir_etiquetas_ejeY,
# Scour processed file "output/barras coloreadas por categorías.svg" in 60 ms: 22103/44580 bytes new/orig -> 49.6%
